# %%
import helper_functions as hf
import importlib

importlib.reload(hf)
# Out:
# <module 'helper_functions' from 'c:\\Users\\Leon\\work\\DS_Project_Feature_Selection\\src\\helper_functions.py'>

# %%
random_baseline = hf.get_random_baseline(n=10000)

# %% [markdown]
# ## Mutual Information Score

# %%
json_files_mutual_info = [
                'results/mutual_info_score_seed0_sub0.001_features-all.json',
                'results/mutual_info_score_seed0_sub0.01_features-all.json',
                'results/mutual_info_score_seed0_sub0.1_features-all.json',
                'results/mutual_info_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_mutual_info, random_baseline)

# %% [markdown]
# ## Anova F Score

# %%
json_files_anova_f = [
                'results/anova_f_score_seed0_sub0.001_features-all.json',
                'results/anova_f_score_seed0_sub0.01_features-all.json',
                'results/anova_f_score_seed0_sub0.1_features-all.json',
                'results/anova_f_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_anova_f, random_baseline)

# %% [markdown]
# ## Pearson Correlation

# %%
json_files_pearson = [
                'results/pearson_correlation_score_seed0_sub0.001_features-all.json',
                'results/pearson_correlation_score_seed0_sub0.01_features-all.json',
                'results/pearson_correlation_score_seed0_sub0.1_features-all.json',
                'results/pearson_correlation_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_pearson, random_baseline)

# %% [markdown]
# ## Chi2 Score

# %%
json_files_chi2_score = [
                'results/chi2_score_seed0_sub0.001_features-all.json',
                'results/chi2_score_seed0_sub0.01_features-all.json',
                'results/chi2_score_seed0_sub0.1_features-all.json',
                'results/chi2_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_chi2_score, random_baseline)

# %% [markdown]
# ## SURF

# %%
json_files_SURF = [
                'results/SURF_score_seed0_sub0.001_features-all.json',
                'results/SURF_score_seed0_sub0.01_features-all.json']

hf.plot_ranking_results_same_algo(json_files_SURF, random_baseline)

# %% [markdown]
# ## SURF star

# %%
json_files_SURFstar = [
                'results/SURFstar_score_seed0_sub0.001_features-all.json',
                'results/SURFstar_score_seed0_sub0.01_features-all.json']

hf.plot_ranking_results_same_algo(json_files_SURFstar, random_baseline)

# %% [markdown]
# ## MultiSURF

# %%
json_files_multiSURF = [
                'results/MultiSURF_score_seed0_sub0.001_features-all.json',
                'results/MultiSURF_score_seed0_sub0.01_features-all.json']

hf.plot_ranking_results_same_algo(json_files_multiSURF, random_baseline)

# %% [markdown]
# ## MultiSURF star

# %%
json_files_multiSURF_star = [
                'results/MultiSURFstar_score_seed0_sub0.001_features-all.json',
                'results/MultiSURFstar_score_seed0_sub0.01_features-all.json']

hf.plot_ranking_results_same_algo(json_files_multiSURF_star, random_baseline)

# %% [markdown]
# ## Random Forest

# %%
json_files_rf = [
                'results/random_forest_score_seed0_sub0.001_features-all.json',
                'results/random_forest_score_seed0_sub0.01_features-all.json',
                'results/random_forest_score_seed0_sub0.1_features-all.json',
                'results/random_forest_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_rf, random_baseline)

# %% [markdown]
# ## XGBOOST

# %%
json_files_xgboost = [
                'results/xgboost_score_seed0_sub0.001_features-all.json',
                'results/xgboost_score_seed0_sub0.01_features-all.json',
                'results/xgboost_score_seed0_sub0.1_features-all.json',
                'results/xgboost_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_xgboost, random_baseline)

# %% [markdown]
# ## ReliefF

# %%
json_files_reliefF = [
                'results/ReliefF_score_seed0_sub0.001_features-all.json',
                'results/ReliefF_score_seed0_sub0.01_features-all.json']

hf.plot_ranking_results_same_algo(json_files_reliefF, random_baseline)

# %% [markdown]
# ## Comparison of multiple algorithms

# %%
importlib.reload(hf)

json_files_comparison = [
                'results/mutual_info_score_seed0_sub0.01_features-all.json',
                'results/anova_f_score_seed0_sub0.01_features-all.json',
                'results/chi2_score_seed0_sub0.01_features-all.json',
                'results/pearson_correlation_score_seed0_sub0.01_features-all.json',
                'results/random_forest_score_seed0_sub0.01_features-all.json',
                'results/ReliefF_score_seed0_sub0.01_features-all.json',
                'results/xgboost_score_seed0_sub0.01_features-all.json',
                'results/mrmr_score_seed0_sub0.01_features-all.json']

hf.plot_ranking_results(json_files_comparison, random_baseline)

# %% [markdown]
# ### MRMR

# %%
json_files_comparison = [
                'results/mrmr_score_seed0_sub0.001_features-all.json',
                'results/mrmr_score_seed0_sub0.01_features-all.json',
                'results/mrmr_score_seed0_sub0.1_features-all.json',
                'results/mrmr_score_seed0_sub1.0_features-all.json']

hf.plot_ranking_results_same_algo(json_files_comparison, random_baseline)
