# %%
import os
import helper_functions as hf
import importlib

importlib.reload(hf)
# Out:
# <module 'helper_functions' from 'A:\\Prog_FaksDataScience\\Project\\DS_Project_Feature_Selection\\src\\helper_functions.py'>

# %%
random_baseline = hf.get_true_baseline()

# %% [markdown]
# ## Mutual Information Score

# %%
importlib.reload(hf)

mutual_info_0_1_folder = "results/mutual_info_0.1_batch"
mutual_info_0_01_folder = "results/mutual_info_0.01_batch"

mutual_info_0_1_files = [os.path.join(mutual_info_0_1_folder, f"mutual_info_score_seed{i}_sub0.1_features-all.json") for i in
                     range(100)]
mutual_info_0_01_files = [os.path.join(mutual_info_0_01_folder, f"mutual_info_score_seed{i}_sub0.01_features-all.json") for i in
                      range(100)]

json_files_list = [
    mutual_info_0_1_files,
    mutual_info_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## Anova F Score

# %%
anova_f_0_1_folder = "results/anova_f_0.1_batch"
anova_f_0_01_folder = "results/anova_f_0.01_batch"

anova_f_0_1_files = [os.path.join(anova_f_0_1_folder, f"anova_f_score_seed{i}_sub0.1_features-all.json") for i in
                     range(100)]
anova_f_0_01_files = [os.path.join(anova_f_0_01_folder, f"anova_f_score_seed{i}_sub0.01_features-all.json") for i in
                      range(100)]

json_files_list = [
    anova_f_0_01_files,
    anova_f_0_1_files,
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## Pearson Correlation

# %%
pearson_corr_0_1_folder = "results/pearson_correlation_0.1_batch"
pearson_corr_0_01_folder = "results/pearson_correlation_0.01_batch"

pearson_corr_0_1_files = [os.path.join(pearson_corr_0_1_folder, f"pearson_correlation_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
pearson_corr_0_01_files = [os.path.join(pearson_corr_0_01_folder, f"pearson_correlation_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    pearson_corr_0_1_files,
    pearson_corr_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ### Pearson abs value

# %%
pearson_corr_0_1_folder = "results/pearson_correlation_0.1_new"
pearson_corr_0_01_folder = "results/pearson_correlation_0.01_new"

pearson_corr_0_1_files = [os.path.join(pearson_corr_0_1_folder, f"pearson_correlation_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
pearson_corr_0_01_files = [os.path.join(pearson_corr_0_01_folder, f"pearson_correlation_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    pearson_corr_0_1_files,
    pearson_corr_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## Chi2 Score

# %%
chi2_0_1_folder = "results/chi2_0.1_batch"
chi2_0_01_folder = "results/chi2_0.01_batch"

chi2_0_1_files = [os.path.join(chi2_0_1_folder, f"chi2_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
chi2_0_01_files = [os.path.join(chi2_0_01_folder, f"chi2_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    chi2_0_1_files,
    chi2_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## Random Forest

# %%
random_forest_0_1_folder = "results/random_forest_0.1_batch"
random_forest_0_01_folder = "results/random_forest_0.01_batch"

random_forest_0_1_files = [os.path.join(random_forest_0_1_folder, f"random_forest_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
random_forest_0_01_files = [os.path.join(random_forest_0_01_folder, f"random_forest_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    random_forest_0_1_files,
    random_forest_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## XGBOOST

# %%
xgboost_0_1_folder = "results/xgboost_0.1_batch"
xgboost_0_01_folder = "results/xgboost_0.01_batch"

xgboost_0_1_files = [os.path.join(xgboost_0_1_folder, f"xgboost_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
xgboost_0_01_files = [os.path.join(xgboost_0_01_folder, f"xgboost_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    xgboost_0_1_files,
    xgboost_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## MRMR

# %%
mrmr_0_1_folder = "results/mrmr_0.1_batch"
mrmr_0_01_folder = "results/mrmr_0.01_batch"

mrmr_0_1_files = [os.path.join(mrmr_0_1_folder, f"mrmr_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
mrmr_0_01_files = [os.path.join(mrmr_0_01_folder, f"mrmr_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    mrmr_0_1_files,
    mrmr_0_01_files
]

hf.plot_ranking_results(json_files_list, random_baseline, plot_type='both')

# %% [markdown]
# ## Comparison of multiple algorithms

# %%
importlib.reload(hf)

json_files_comparison = [
    mutual_info_0_1_files,
    anova_f_0_1_files,
    pearson_corr_0_1_files,
    chi2_0_1_files,
    random_forest_0_1_files,
    xgboost_0_1_files,
    mrmr_0_1_files
]

hf.plot_ranking_results(json_files_comparison, random_baseline)
