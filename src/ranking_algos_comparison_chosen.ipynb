# %%
import os
import helper_functions as hf
import importlib

importlib.reload(hf)

import statsmodels.stats.proportion as smp

# %%
random_baseline = hf.get_true_baseline()

# %% [markdown]
# ## Mutual Information Score

# %%
importlib.reload(hf)

mutual_info_0_1_folder = "results/mutual_info_0.1_batch"
mutual_info_0_01_folder = "results/mutual_info_0.01_batch"

mutual_info_0_1_files = [os.path.join(mutual_info_0_1_folder, f"mutual_info_score_seed{i}_sub0.1_features-all.json") for i in
                     range(100)]
mutual_info_0_01_files = [os.path.join(mutual_info_0_01_folder, f"mutual_info_score_seed{i}_sub0.01_features-all.json") for i in
                      range(100)]

json_files_list = [
    mutual_info_0_1_files,
    mutual_info_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## Anova F Score

# %%
anova_f_0_1_folder = "results/anova_f_0.1_batch"
anova_f_0_01_folder = "results/anova_f_0.01_batch"

anova_f_0_1_files = [os.path.join(anova_f_0_1_folder, f"anova_f_score_seed{i}_sub0.1_features-all.json") for i in
                     range(100)]
anova_f_0_01_files = [os.path.join(anova_f_0_01_folder, f"anova_f_score_seed{i}_sub0.01_features-all.json") for i in
                      range(100)]

json_files_list = [
    anova_f_0_01_files,
    anova_f_0_1_files,
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## Pearson Correlation

# %%
pearson_corr_0_1_folder = "results/pearson_correlation_0.1_batch"
pearson_corr_0_01_folder = "results/pearson_correlation_0.01_batch"

pearson_corr_0_1_files = [os.path.join(pearson_corr_0_1_folder, f"pearson_correlation_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
pearson_corr_0_01_files = [os.path.join(pearson_corr_0_01_folder, f"pearson_correlation_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    pearson_corr_0_1_files,
    pearson_corr_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ### Pearson abs value

# %%
pearson_corr_0_1_folder = "results/pearson_correlation_0.1_new"
pearson_corr_0_01_folder = "results/pearson_correlation_0.01_new"

pearson_corr_0_1_files = [os.path.join(pearson_corr_0_1_folder, f"pearson_correlation_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
pearson_corr_0_01_files = [os.path.join(pearson_corr_0_01_folder, f"pearson_correlation_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    pearson_corr_0_1_files,
    pearson_corr_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## Chi2 Score

# %%
chi2_0_1_folder = "results/chi2_0.1_batch"
chi2_0_01_folder = "results/chi2_0.01_batch"

chi2_0_1_files = [os.path.join(chi2_0_1_folder, f"chi2_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
chi2_0_01_files = [os.path.join(chi2_0_01_folder, f"chi2_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    chi2_0_1_files,
    chi2_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## Random Forest

# %%
random_forest_0_1_folder = "results/random_forest_0.1_batch"
random_forest_0_01_folder = "results/random_forest_0.01_batch"

random_forest_0_1_files = [os.path.join(random_forest_0_1_folder, f"random_forest_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
random_forest_0_01_files = [os.path.join(random_forest_0_01_folder, f"random_forest_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    random_forest_0_1_files,
    random_forest_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## XGBOOST

# %%
xgboost_0_1_folder = "results/xgboost_0.1_batch"
xgboost_0_01_folder = "results/xgboost_0.01_batch"

xgboost_0_1_files = [os.path.join(xgboost_0_1_folder, f"xgboost_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
xgboost_0_01_files = [os.path.join(xgboost_0_01_folder, f"xgboost_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    xgboost_0_1_files,
    xgboost_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## MRMR

# %%
mrmr_0_1_folder = "results/mrmr_0.1_batch"
mrmr_0_01_folder = "results/mrmr_0.01_batch"

mrmr_0_1_files = [os.path.join(mrmr_0_1_folder, f"mrmr_score_seed{i}_sub0.1_features-all.json") for i in range(100)]
mrmr_0_01_files = [os.path.join(mrmr_0_01_folder, f"mrmr_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

json_files_list = [
    mrmr_0_1_files,
    mrmr_0_01_files
]

hf.plot_ranking_results(json_files_list, plot_type='both')

# %% [markdown]
# ## Comparison of multiple algorithms

# %%
importlib.reload(hf)

json_files_comparison = [
    mutual_info_0_1_files,
    anova_f_0_1_files,
    pearson_corr_0_1_files,
    chi2_0_1_files,
    random_forest_0_1_files,
    xgboost_0_1_files,
    mrmr_0_1_files
]

hf.plot_ranking_results(json_files_comparison)

# %%
import numpy as np
import matplotlib.pyplot as plt
import json
import math

def get_true_baseline(T=100):
    """
    Replaces the old get_random_baseline with an analytical solution.

    :param T: The number of features we are ranking.

    :return: A numpy array containing the expected value for a random permutaiton for each k.
    """
    def probability(i, j, t, T):
        return math.comb(t, i) * math.comb(T - t, j) / math.comb(T, t)

    def expected_score(t, T):
        e_t = 0
        for i in range(t + 1):
            j = t - i
            e_t += probability(i, j, t, T) * (i / (2 * t - i))
        return e_t

    baseline = [expected_score(t, T) for t in range(1, T + 1)]

    return np.array(baseline)

def plot_ranking_results(json_files_list, plot_type='both'):
    categories = ['first_gen', 'singles']
    if plot_type in categories:
        categories = [plot_type]

    ncols = 1 if plot_type != 'both' else 2
    fig, axes = plt.subplots(nrows=1, ncols=ncols, figsize=(10 * ncols, 5))
    if ncols == 1:
        axes = [axes]

    colorblind_colors = ['#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#CC79A7', '#999999']
    linestyles = ['-', '--', ':', '-.', (0, (1, 1)), (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1, 1, 1)), (0, (5, 1))]

    for ax, category in zip(axes, categories):
        for idx, json_files in enumerate(json_files_list):
            results = []
            for file in json_files:
                with open(file, 'r') as f:
                    data = json.load(f)
                    rank_algo = data["rank_algo"]
                    subsampling_proportion = data["subsampling_proportion"]
                    ranking_results = data["evaluations"][category][0]
                    results.append(ranking_results)

            num_features = len(results[0])  # number of features (k)
            k_list = range(1, num_features + 1)  # k range

            # remove 5 most extreme outliers
            results = np.array(results)
            #results = np.sort(results, axis=0)[5:-5, :]
            mean_results = np.mean(results, axis=0)
            # get max and min values for each k
            max_results = np.max(results, axis=0)
            min_results = np.min(results, axis=0)

            ax.plot(k_list, mean_results, label=f'{rank_algo} ({subsampling_proportion})',
                    color=colorblind_colors[idx % len(colorblind_colors)], linestyle=linestyles[idx % len(linestyles)])
            ax.fill_between(k_list, min_results, max_results, alpha=0.2,
                            color=colorblind_colors[idx % len(colorblind_colors)])

        random_baseline = get_true_baseline(T=num_features)

        ax.plot(k_list, random_baseline, label='random ranking', color='grey')

        ax.set_title(category.replace('_', ' ').title(), fontsize=18)
        ax.set_xlabel('k')
        ax.set_ylabel('Jaccard score')

        ax.tick_params(axis='both', which='major', labelsize=15)
        ax.xaxis.label.set_size(16)
        ax.yaxis.label.set_size(16)

        xticks = np.linspace(1, num_features, 6).astype(int)
        ax.set_xticks(xticks)

        ax.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5)

    if ncols == 2:
        axes[-1].legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', borderaxespad=0., prop={'size': 15})
    else:
        axes[0].legend(loc='lower right', prop={'size': 15})

    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.savefig(f'img/ranking_comparison_chosen.png', dpi=400, bbox_inches='tight')
    plt.show()

# %%
def calculate_confidence_interval(data, confidence_level=0.95):
    """
    Calculates the confidence interval for binomial distribution
    :param data: list of results from the process. 1 for success, 0 for failure
    :param confidence_level: confidence level for the interval
    :return: lower and upper confidence interval
    """
    # Number of trials and successes
    n = len(data)
    x = np.sum(data)

    # Calculate confidence intervals
    lower, upper = smp.proportion_confint(x, n, alpha=(1-confidence_level))

    return lower, upper

# %%
plt.style.use('default')
def plot_ranking_results(json_files_list):
    categories = ['first_gen', 'singles']
    ncols = 2
    fig, axes = plt.subplots(nrows=1, ncols=ncols, figsize=(20, 5))

    colorblind_colors = ['#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#CC79A7', '#999999']
    linestyles = ['-', '--', ':', '-.', (0, (1, 1)), (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1, 1, 1)), (0, (5, 1))]

    # First category
    ax = axes[0]
    category = categories[0]

    labels = ["Chi Squared", "Random Forest", "ReliefF"]

    for idx, json_files in enumerate(json_files_list):
        results = []
        for file in json_files:
            with open(file, 'r') as f:
                data = json.load(f)
                rank_algo = data["rank_algo"]
                subsampling_proportion = data["subsampling_proportion"]
                ranking_results = data["evaluations"][category][0]
                results.append(ranking_results)

        num_features = len(results[0])  # number of features (k)
        k_list = range(1, num_features + 1)  # k range

        # remove 5 most extreme outliers
        results = np.array(results)
        mean_results = np.mean(results, axis=0)
        max_results = np.max(results, axis=0)
        min_results = np.min(results, axis=0)

        print("min", min_results)
        print("max", max_results)

        min_results, max_results = calculate_confidence_interval(results)

        # Manually set labels
        label = labels[idx]

        ax.plot(k_list, mean_results, label=label,
                color=colorblind_colors[idx % len(colorblind_colors)], linestyle=linestyles[idx % len(linestyles)])
        ax.fill_between(k_list, min_results, max_results, alpha=0.8,
                        color=colorblind_colors[idx % len(colorblind_colors)])

    random_baseline = get_true_baseline(T=num_features)
    ax.plot(k_list, random_baseline, label='baseline', color='grey')
    ax.set_title("Single feature model-based ranking", fontsize=18)
    ax.set_xlabel('k')
    ax.set_ylabel('Jaccard score')
    ax.tick_params(axis='both', which='major', labelsize=15)
    ax.xaxis.label.set_size(16)
    ax.yaxis.label.set_size(16)
    xticks = np.linspace(1, num_features, 6).astype(int)
    ax.set_xticks(xticks)
    ax.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5)

    '''# add diagonal line
    ax.plot([80, 85], [0.6, 0.4], color='black', linestyle='-', linewidth=1.5)
    #ax.axvline(x=80, ymin=0.4, ymax=0.6, color='grey', linestyle='-', linewidth=0.5)
    ax.text(72, 0.33, 'uninformative threshold', fontsize=16)'''

    # Second category
    ax = axes[1]
    category = categories[1]

    for idx, json_files in enumerate(json_files_list):
        results = []
        for file in json_files:
            with open(file, 'r') as f:
                data = json.load(f)
                rank_algo = data["rank_algo"]
                subsampling_proportion = data["subsampling_proportion"]
                ranking_results = data["evaluations"][category][0]
                results.append(ranking_results)

        num_features = len(results[0])  # number of features (k)
        k_list = range(1, num_features + 1)  # k range

        # remove 5 most extreme outliers
        results = np.array(results)
        mean_results = np.mean(results, axis=0)
        max_results = np.max(results, axis=0)
        min_results = np.min(results, axis=0)

        # Manually set labels
        label = labels[idx]

        ax.plot(k_list, mean_results, label=label,
                color=colorblind_colors[idx % len(colorblind_colors)], linestyle=linestyles[idx % len(linestyles)])
        ax.fill_between(k_list, min_results, max_results, alpha=0.2,
                        color=colorblind_colors[idx % len(colorblind_colors)])

    random_baseline = get_true_baseline(T=num_features)
    ax.plot(k_list, random_baseline, label='Baseline', color='grey')
    ax.set_title("Forward selection ranking", fontsize=18)
    ax.set_xlabel('k')
    ax.tick_params(axis='both', which='major', labelsize=15)
    ax.xaxis.label.set_size(16)
    xticks = np.linspace(1, num_features, 6).astype(int)
    ax.set_xticks(xticks)
    ax.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5)

    # Legend
    #axes[-1].legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', borderaxespad=0., prop={'size': 15})

    # add legend to the last subplot
    ax.legend(loc='lower right', prop={'size': 15})


    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.savefig(f'img/ranking_comparison_chosen_nosidelegend.png', dpi=400, bbox_inches='tight')
    plt.show()

# %%
relieff_0_01_folder = "results/relieff_0.01_batch"
reliefF_0_01_files = [os.path.join(relieff_0_01_folder, f"ReliefF_score_seed{i}_sub0.01_features-all.json") for i in range(100)]

# %%
json_files_comparison = [
    chi2_0_01_files,
    random_forest_0_01_files,
    reliefF_0_01_files
]

plot_ranking_results(json_files_comparison)
# Out:
# min [0.         0.         0.         0.         0.         0.
#  0.07692308 0.23076923 0.28571429 0.33333333 0.375      0.33333333
#  0.36842105 0.4        0.36363636 0.33333333 0.41666667 0.38461538
#  0.35714286 0.33333333 0.35483871 0.33333333 0.35294118 0.37142857
#  0.35135135 0.36842105 0.38461538 0.4        0.41463415 0.39534884
#  0.40909091 0.39130435 0.375      0.3877551  0.4        0.38461538
#  0.39622642 0.43396226 0.44444444 0.42857143 0.43859649 0.44827586
#  0.43333333 0.41935484 0.40625    0.39393939 0.42424242 0.43283582
#  0.46268657 0.49253731 0.52238806 0.52941176 0.55882353 0.58823529
#  0.57142857 0.6        0.62857143 0.63380282 0.66197183 0.69014085
#  0.71830986 0.69863014 0.7027027  0.70666667 0.71052632 0.69230769
#  0.69620253 0.7        0.68292683 0.66666667 0.67058824 0.65517241
#  0.64044944 0.62637363 0.61290323 0.61702128 0.60416667 0.60824742
#  0.5959596  0.61616162 0.63636364 0.64       0.66       0.68
# ...

# %% [markdown]
# ## ENSEMBLE BEFORE AFTER

# %%
def get_files_list(subsample_proportion, directory, hash='all'):
    """
    Returns a list of files that match the given subsampling proportion and hash value.

    Args:
        subsample_proportion (float): The desired subsampling proportion.
        directory (str): The directory path where the files are located.
        hash (str, optional): The hash value to filter the files (default: 'all').

    Returns:
        list: A list of files that match the specified subsampling proportion and hash value.
    """
    files = []

    all_files = os.listdir(directory)
    for file in all_files:
        if (f"sub{subsample_proportion}_" in file and f"features-{hash}" in file):
            files.append(directory + file)

    return files

# %%
def plot_ranking_results(json_files_list):
    fig, ax = plt.subplots(figsize=(10, 5))

    colorblind_colors = ['#E69F00', '#56B4E9', '#009E73', '#F0E442', '#0072B2', '#D55E00', '#CC79A7', '#999999']
    linestyles = ['-', '--', ':', '-.', (0, (1, 1)), (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1, 1, 1)), (0, (5, 1))]

    category = 'first_gen'
    labels = ["Individual rankings", "Ensemble ranking"]

    for idx, json_files in enumerate(json_files_list):
        results = []
        for file in json_files:
            with open(file, 'r') as f:
                data = json.load(f)
                rank_algo = data["rank_algo"]
                subsampling_proportion = data["subsampling_proportion"]
                ranking_results = data["evaluations"][category][0]
                results.append(ranking_results)

        num_features = len(results[0])  # number of features (k)
        k_list = range(1, num_features + 1)  # k range

        # remove 5 most extreme outliers
        results = np.array(results)
        mean_results = np.mean(results, axis=0)
        max_results = np.max(results, axis=0)
        min_results = np.min(results, axis=0)

        # Manually set labels
        label = labels[idx]

        ax.plot(k_list, mean_results, label=label,
                color=colorblind_colors[idx % len(colorblind_colors)], linestyle=linestyles[idx % len(linestyles)])
        ax.fill_between(k_list, min_results, max_results, alpha=0.2,
                        color=colorblind_colors[idx % len(colorblind_colors)])

    random_baseline = get_true_baseline(T=num_features)
    ax.plot(k_list, random_baseline, label='Baseline', color='grey')
    ax.set_xlabel('k')
    ax.set_ylabel('Jaccard score')
    ax.tick_params(axis='both', which='major', labelsize=15)
    ax.xaxis.label.set_size(16)
    ax.yaxis.label.set_size(16)
    xticks = np.linspace(1, num_features, 6).astype(int)
    ax.set_xticks(xticks)
    ax.grid(True, which='both', axis='both', linestyle='--', linewidth=0.5)

    ax.legend(loc='lower right', prop={'size': 16})

    plt.tight_layout(rect=[0, 0, 1, 1])
    plt.savefig(f'img/rf_performance_ensemble_vs_individual.png', dpi=400, bbox_inches='tight')
    plt.show()

# %%
plot_ranking_results([get_files_list(0.0001, "results/random_forest_optimization/"),["results/ensemble_score_sub0.0001.json"]*100])
